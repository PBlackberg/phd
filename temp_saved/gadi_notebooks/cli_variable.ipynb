# %%
import xarray as xr

# %%
a = xr.open_dataset('/g/data/oi10/replicas/CMIP6/CMIP/MIROC/MIROC6/historical/r1i1p1f1/Amon/cli/gn/v20190311/cli_Amon_MIROC6_historical_r1i1p1f1_gn_197001-197912.nc')
a
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/share/proj failed
# <xarray.Dataset>
# Dimensions:    (time: 120, bnds: 2, lev: 81, lat: 128, lon: 256)
# Coordinates:
#   * time       (time) datetime64[ns] 1970-01-16T12:00:00 ... 1979-12-16T12:00:00
#   * lev        (lev) float64 0.9975 0.9915 0.983 ... 1.466e-05 3.879e-06
#   * lat        (lat) float64 -88.93 -87.54 -86.14 -84.74 ... 86.14 87.54 88.93
#   * lon        (lon) float64 0.0 1.406 2.812 4.219 ... 354.4 355.8 357.2 358.6
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] ...
#     lev_bnds   (lev, bnds) float64 ...
#     p0         float64 ...
#     a          (lev) float64 ...
#     b          (lev) float64 ...
#     ps         (time, lat, lon) float32 ...
#     a_bnds     (lev, bnds) float64 ...
#     b_bnds     (lev, bnds) float64 ...
#     lat_bnds   (lat, bnds) float64 ...
# ...
