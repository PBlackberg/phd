# %%
import intake

# %%
era5 = intake.cat['nci']['era5']

# %%
df = era5.df

# %%
df.head()
# Out:
#   sub_collection          dataset             product_type parameter  year  \
# 0         era5-1  pressure-levels  monthly-averaged-by-day        cc  2000
# 1         era5-1  pressure-levels  monthly-averaged-by-day        cc  2000
# 2         era5-1  pressure-levels  monthly-averaged-by-day        cc  2000
# 3         era5-1  pressure-levels  monthly-averaged-by-day        cc  2000
# 4         era5-1  pressure-levels  monthly-averaged-by-day        cc  2000
#
#    month  startdate file_variable  \
# 0      1   20000101            cc
# 1      2   20000201            cc
# 2      3   20000301            cc
# 3      4   20000401            cc
# 4      5   20000501            cc
#
#                                                 path
# 0  /g/data/rt52/era5-1/pressure-levels/monthly-av...
# 1  /g/data/rt52/era5-1/pressure-levels/monthly-av...
# 2  /g/data/rt52/era5-1/pressure-levels/monthly-av...
# 3  /g/data/rt52/era5-1/pressure-levels/monthly-av...
# ...

# %%
print(era5.unique()['parameter'])
# Out:
# ['cc', 'ciwc', 'clwc', 'crwc', 'cswc', 'd', 'o3', 'pv', 'q', 'r', 't', 'u', 'v', 'vo', 'w', 'z', '100u', '100v', '10si', '10u', '10v', '2d', '2t', 'alnid', 'alnip', 'aluvd', 'aluvp', 'anor', 'asn', 'bfi', 'bld', 'blh', 'cape', 'cbh', 'cdir', 'cdww', 'chnk', 'ci', 'cin', 'cl', 'cp', 'crr', 'csf', 'csfr', 'cvh', 'cvl', 'dctb', 'deg0l', 'dl', 'dndza', 'dndzn', 'dwi', 'dwps', 'dwww', 'e', 'es', 'ewss', 'fal', 'fdir', 'flsr', 'fsr', 'gwd', 'hcc', 'hmax', 'i10fg', 'ie', 'iews', 'ilspf', 'inss', 'ishf', 'isor', 'istl1', 'istl2', 'istl3', 'istl4', 'kx', 'lai_hv', 'lai_lv', 'lblt', 'lcc', 'lgws', 'licd', 'lict', 'lmld', 'lmlt', 'lsf', 'lshf', 'lsm', 'lsp', 'lspf', 'lsrr', 'lssfr', 'ltlt', 'magss', 'mbld', 'mcc', 'mcpr', 'mcsr', 'mdts', 'mdww', 'megwss', 'mer', 'metss', 'mgwd', 'mgws', 'mlspf', 'mlspr', 'mlssr', 'mmtss', 'mngwss', 'mntss', 'mp1', 'mp2', 'mper', 'mpts', 'mpww', 'mror', 'msdrswrf', 'msdrswrfcs', 'msdwlwrf', 'msdwlwrfcs', 'msdwswrf', 'msdwswrfcs', 'msdwuvrf', 'mser', 'msl', 'mslh
# ...

# %%
sub = era5.search(sub_collection = 'era5',  product_type ='monthly-averaged', parameter = 'r')
sub
# Out:
# <p><strong>era5 catalog with 1 dataset(s) from 776 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>sub_collection</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>dataset</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>product_type</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>parameter</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>year</th>
#       <td>65</td>
#     </tr>
#     <tr>
#       <th>month</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>startdate</th>
#       <td>776</td>
#     </tr>
#     <tr>
# ...

# %%
# print(sub.unique()['product_type'])
# Out:
# ['monthly-averaged-by-hour', 'monthly-averaged', 'reanalysis']

# %%
print(sub.unique()['path'][0])
# Out:
# /g/data/rt52/era5/pressure-levels/monthly-averaged/r/1959/r_era5_moda_pl_19590101-19590131.nc

# %%
import xarray as xr

# %%
a = xr.open_dataset('/g/data/rt52/era5/pressure-levels/monthly-averaged/r/1959/r_era5_moda_pl_19590101-19590131.nc')
a
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/share/proj failed
# <xarray.Dataset>
# Dimensions:    (longitude: 1440, latitude: 721, level: 37, time: 1)
# Coordinates:
#   * longitude  (longitude) float32 -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * level      (level) int32 1 2 3 5 7 10 20 30 ... 850 875 900 925 950 975 1000
#   * time       (time) datetime64[ns] 1959-01-01
# Data variables:
#     r          (time, level, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-07-30 02:45:12 UTC+1000 by era5_replication_tools-1.10...
#     license:      Licence to use Copernicus Products: https://apps.ecmwf.int/...
#     summary:      ERA5 is the fifth generation ECMWF atmospheric reanalysis o...
#     title:        ERA5 pressure-levels monthly-averaged relative_humidity 195...

# %%
a = xr.open_dataset('/g/data/rt52/era5/pressure-levels/monthly-averaged/z/1959/z_era5_moda_pl_19590101-19590131.nc')
a
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/share/proj failed
# <xarray.Dataset>
# Dimensions:    (longitude: 1440, latitude: 721, level: 37, time: 1)
# Coordinates:
#   * longitude  (longitude) float32 -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * level      (level) int32 1 2 3 5 7 10 20 30 ... 850 875 900 925 950 975 1000
#   * time       (time) datetime64[ns] 1959-01-01
# Data variables:
#     z          (time, level, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2022-07-30 02:45:11 UTC+1000 by era5_replication_tools-1.10...
#     license:      Licence to use Copernicus Products: https://apps.ecmwf.int/...
#     summary:      ERA5 is the fifth generation ECMWF atmospheric reanalysis o...
#     title:        ERA5 pressure-levels monthly-averaged geopotential 19590101...
