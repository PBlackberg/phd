# %%
import xarray as xr

# %%
a = xr.open_dataset('/g/data/oi10/replicas/CMIP6/ScenarioMIP/NIMS-KMA/KACE-1-0-G/ssp585/r1i1p1f1/Amon/hus/gr/v20190920/hus_Amon_KACE-1-0-G_ssp585_r1i1p1f1_gr_201501-210012.nc')
a
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1032, bnds: 2, plev: 19, lat: 144, lon: 192)
# Coordinates:
#   * time       (time) object 2015-01-16 00:00:00 ... 2100-12-16 00:00:00
#   * plev       (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * lat        (lat) float64 -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#   * lon        (lon) float64 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) object ...
#     lat_bnds   (lat, bnds) float64 ...
#     lon_bnds   (lon, bnds) float64 ...
#     hus        (time, plev, lat, lon) float32 ...
# Attributes: (12/46)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            ScenarioMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  0.0
#     contact:                Yoon-Jin Lim (yoonjin.lim@korea.kr)
#     ...                     ...
# ...

# %%
r= a['hus'].sel(time=slice('2070','2099'))
r
# Out:
# <xarray.DataArray 'hus' (time: 360, plev: 19, lat: 144, lon: 192)>
# [189112320 values with dtype=float32]
# Coordinates:
#   * time     (time) object 2070-01-16 00:00:00 ... 2099-12-16 00:00:00
#   * plev     (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * lat      (lat) float64 -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#   * lon      (lon) float64 0.9375 2.812 4.688 6.562 ... 353.4 355.3 357.2 359.1
# Attributes:
#     standard_name:  specific_humidity
#     long_name:      Specific Humidity
#     comment:        Specific humidity is the mass fraction of water vapor in ...
#     units:          1
#     original_name:  m01s30i205
#     cell_methods:   time: mean (interval: 1 month)
#     cell_measures:  area: areacella
#     history:        2019-09-20T10:51:59Z altered by CMOR: Reordered dimension...

# %%
a = xr.open_dataset('/g/data/oi10/replicas/CMIP6/ScenarioMIP/NIMS-KMA/KACE-1-0-G/ssp585/r1i1p1f1/Amon/ta/gr/v20190920/ta_Amon_KACE-1-0-G_ssp585_r1i1p1f1_gr_201501-210012.nc')
a
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1032, bnds: 2, plev: 19, lat: 144, lon: 192)
# Coordinates:
#   * time       (time) object 2015-01-16 00:00:00 ... 2100-12-16 00:00:00
#   * plev       (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * lat        (lat) float64 -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#   * lon        (lon) float64 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) object ...
#     lat_bnds   (lat, bnds) float64 ...
#     lon_bnds   (lon, bnds) float64 ...
#     ta         (time, plev, lat, lon) float32 ...
# Attributes: (12/46)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            ScenarioMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  0.0
#     contact:                Yoon-Jin Lim (yoonjin.lim@korea.kr)
#     ...                     ...
# ...

# %%
T = a['ta'].sel(time=slice('1970','2099'))
T
# Out:
# <xarray.DataArray 'ta' (time: 1020, plev: 19, lat: 144, lon: 192)>
# [535818240 values with dtype=float32]
# Coordinates:
#   * time     (time) object 2015-01-16 00:00:00 ... 2099-12-16 00:00:00
#   * plev     (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * lat      (lat) float64 -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#   * lon      (lon) float64 0.9375 2.812 4.688 6.562 ... 353.4 355.3 357.2 359.1
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Air Temperature
#     comment:        Air Temperature
#     units:          K
#     original_name:  m01s30i204
#     cell_methods:   time: mean (interval: 1 month)
#     cell_measures:  area: areacella
#     history:        2019-09-20T10:18:04Z altered by CMOR: Reordered dimension...

# %%
import numpy as np

# %%
p = T['plev']                                                 # Pa
e_s = 611.2 * np.exp(17.67*(T-273.15)/(T-29.66))              # saturation water vapor pressure
r_s = 0.622 * e_s/p
da = (r/r_s)*100                                              # relative humidity could do e/e_s
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/xarray/core/computation.py:761: RuntimeWarning: overflow encountered in exp
#   result_data = func(*input_data)

# %%
plevs = [850e2, 0]
plevs = slice(plevs[0], plevs[1])
da = da.sel(plev=plevs)
da = (da * da.plev).sum(dim='plev') / da.plev.sum(dim='plev') # free troposphere (most values at 1000 hPa over land are NaN)

# %%
da
# Out:
# <xarray.DataArray (time: 360, lat: 144, lon: 192)>
# array([[[40.73112849, 40.78370579, 40.74685371, ..., 40.38390864,
#          40.47952591, 40.63648126],
#         [38.56632492, 38.65908234, 38.7043898 , ..., 38.36703991,
#          38.42333222, 38.49632966],
#         [36.31702094, 36.58802116, 36.74806301, ..., 35.85343846,
#          35.96198785, 36.09336761],
#         ...,
#         [56.01024972, 56.30894093, 56.44385072, ..., 55.65038487,
#          55.75497661, 55.83357274],
#         [55.14684269, 55.39095967, 55.54272256, ..., 54.78037501,
#          54.8158499 , 54.95851461],
#         [55.20653222, 55.24998687, 55.27863063, ..., 55.09219097,
#          55.12852567, 55.1699381 ]],
#
#        [[27.08560808, 27.09874661, 27.10953916, ..., 27.04886029,
#          27.061054  , 27.07033614],
#         [38.90196683, 39.13069252, 39.00361681, ..., 39.1862406 ,
#          38.54604416, 38.34505247],
#         [40.02043276, 40.03310095, 39.27624533, ..., 39.54962638,
# ...

# %%
da.mean(dim='time').plot()

# %%
da.isel(time=0).plot()

# %%
da.mean(dim='time').plot()

# %%
da.plot()

# %%
a = 5

# %%
if a == 5 and 'plev' in da.dims:
    print('executes')
# Out:
# executes

# %%
da.sel(plev = da.plev[0]).plot()

# %%
da.plev[0]
# Out:
# <xarray.DataArray 'plev' ()>
# array(100000.00000001)
# Coordinates:
#     time     datetime64[ns] 1950-01-16T12:00:00
#     plev     float64 1e+05
# Attributes:
#     bounds:         plev_bnds
#     units:          Pa
#     axis:           Z
#     positive:       down
#     long_name:      pressure
#     standard_name:  air_pressure

# %%
da['plev'] = da['plev'].round(0)

# %%
da.plev[0]
# Out:
# <xarray.DataArray 'plev' ()>
# array(100000.)
# Coordinates:
#     time     datetime64[ns] 1950-01-16T12:00:00
#     plev     float64 1e+05
# Attributes:
#     bounds:         plev_bnds
#     units:          Pa
#     axis:           Z
#     positive:       down
#     long_name:      pressure
#     standard_name:  air_pressure

# %%
da.sel(plev = 1000e2)
# Out:
# <xarray.DataArray 'wap' (lat: 144, lon: 192)>
# [27648 values with dtype=float32]
# Coordinates:
#     time     datetime64[ns] 1950-01-16T12:00:00
#     plev     float64 1e+05
#   * lat      (lat) float64 -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#   * lon      (lon) float64 0.9375 2.812 4.688 6.562 ... 353.4 355.3 357.2 359.1
# Attributes:
#     standard_name:  lagrangian_tendency_of_air_pressure
#     long_name:      Omega (=dp/dt)
#     comment:        Omega (vertical velocity in pressure coordinates, positiv...
#     units:          Pa s-1
#     cell_methods:   time: mean
#     cell_measures:  area: areacella
#     history:        2019-11-21T06:04:08Z altered by CMOR: replaced missing va...

# %%
da.sel(plev = 1000e2).plot()
