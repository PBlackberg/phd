# %%
import xarray as xr

# %%
a = xr.open_dataset('/g/data/k10/cb4968/data/metrics/h_anom2/h_anom2_snapshot/obs/ERA5_h_anom2_snapshot_monthly__regridded.nc')
a
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/share/proj failed
# <xarray.Dataset>
# Dimensions:           (lat: 22, lon: 128)
# Coordinates:
#     time              datetime64[ns] ...
#   * lat               (lat) float64 -29.3 -26.51 -23.72 ... 23.72 26.51 29.3
#   * lon               (lon) float64 0.0 2.812 5.625 8.438 ... 351.6 354.4 357.2
#     plev              int64 ...
# Data variables:
#     h_anom2_snapshot  (lat, lon) float64 ...

# %%
a['h_anom2_snapshot'].plot()
