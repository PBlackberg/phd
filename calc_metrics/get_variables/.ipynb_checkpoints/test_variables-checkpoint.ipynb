# %% [markdown]
# ### import functions

# %%
import xarray as xr
import xesmf as xe
import numpy as np
import os
import scipy
 # cd /g/data/k10/cb4968/phd/calc_metrics/get_variables

# %%
pwd
# Out:
# '/home/565/cb4968'

# %%
cd /g/data/k10/cb4968/phd/calc_metrics
# Out:
# /g/data/k10/cb4968/phd/calc_metrics

# %%
pwd
# Out:
# '/g/data/k10/cb4968/phd/calc_metrics'

# %%
from get_variables.cmip6_variables import *

# %% [markdown]
# ### test variables (cmip6)

# %%
# available models
models = [
    # 'TaiESM1',        # 1 # rcp run has monthly
    # 'BCC-CSM2-MR',    # 2 # rcp monthly   
    'FGOALS-g3',        # 3 # rcp 0463 - 0614
    # 'CNRM-CM6-1',     # 4 # rcp 1850-1999
    # 'MIROC6',         # 5 # rcp 3200 - 3340
    # 'MPI-ESM1-2-HR',  # 6 # rcp 1850 - 2014
    # 'NorESM2-MM',     # 7 # rcp 0001 - 0141
    # 'GFDL-CM4',       # 8 # rcp 0001 - 0141 (gr2)
    # 'CanESM5',        # 9 # rcp 1850 - 2000
    # 'CMCC-ESM2',      # 10 # rcp monthly
    # 'UKESM1-0-LL',    # 11 # rcp 1850 - 1999
    # 'MRI-ESM2-0',     # 12 # rcp 1850 - 2000
    # 'CESM2',          # 13 # rcp 0001 - 0990  (multiple fill values (check if all get converted to NaN), for historical)
    # 'NESM3',          # 12 # rcp 1850-2014
        ]


resolutions = [
    'original',
    # 'regridded'
    ]

experiments = [
            # 'historical',
            'abrupt-4xCO2'
            ]

institutes = {
    'TaiESM1':'AS-RCEC',
    'BCC-CSM2-MR':'BCC',
    'FGOALS-g3':'CAS',
    'CNRM-CM6-1':'CNRM-CERFACS',
    'MIROC6':'MIROC',
    'MPI-ESM1-2-HR':'MPI-M',
    'GISS-E2-1-H':'NASA-GISS',
    'NorESM2-MM':'NCC',
    'GFDL-CM4':'NOAA-GFDL',
    'CanESM5':'CCCma',
    'CMCC-ESM2':'CMCC',
    'UKESM1-0-LL':'MOHC',
    'MRI-ESM2-0':'MRI',
    'CESM2':'NCAR',
    'NESM3':'NUIST'
    }


# not included:
# 'IITM-ESM':'CCCR-IITM'
# 'EC-Earth3':'EC-Earth-Consortium'
# 'HAMMOZ-Consortium':'MPI-ESM-1-2-HAM'
# 'IPSL-CM6A-LR':'IPSL'
# 'GISS-E2-1-H':'NASA-GISS' (only monthly for all variables)
# 'SNU':'SAM0-UNICON'
# 'MCM-UA-1-0':UA
# 'AWI-CM-1-1-MR':AWI
# 'CAMS-CSM1-0':'CAMS'
# 'E3SM-1-0':'E3SM-Project'
# 'FIO-ESM-2-0':'FIO-QLNM'
# 'INM-CM5-0':'INM'
# 'KIOST-ESM':'KIOST'
# 'KACE-1-0-G':'NIMS-KMA' (this institute has data for UKESM1-0-LL which is already included from a different institute)
# 'CIESM':'THU'

# %%
for model in models:
    for experiment in experiments:
        ds_pr = get_pr(institutes[model], model, experiment, resolution=resolutions[0])

# %%
ds_pr
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 10957, lat: 38, lon: 192)
# Coordinates:
#   * time     (time) datetime64[ns] 1970-01-01T12:00:00 ... 1999-12-31T12:00:00
#   * lat      (lat) float64 -34.51 -32.64 -30.78 -28.91 ... 30.78 32.64 34.51
#   * lon      (lon) float64 0.0 1.875 3.75 5.625 7.5 ... 352.5 354.4 356.2 358.1
# Data variables:
#     precip   (time, lat, lon) float32 dask.array<chunksize=(3652, 38, 192), meta=np.ndarray>
# Attributes: (12/46)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  109573.0
#     contact:                esmc@nuist.edu.cn
#     ...                     ...
#     title:                  NESM3 output prepared for CMIP6
#     tracking_id:            hdl:21.14100/78610a40-ea22-4b1b-8382-9924dd149b97
#     variable_id:            pr
#     variant_label:          r1i1p1f1
#     license:                CMIP6 model data produced by Lawrence Livermore P...
#     cmor_version:           3.4.0

# %%
folder = '/g/data/k10/cb4968/data/cmip6/ds/precip'

save_pr = False
if save_pr:
    fileName = model + '_precip_' + experiment + '.nc'
    save_file(ds_pr, folder, fileName)

# %%
ds_pr = xr.open_dataset('/g/data/oi10/replicas/CMIP6/CMIP/CAS/FGOALS-g3/abrupt-4xCO2/r1i1p1f1/day/pr/gn/v20191231/pr_day_FGOALS-g3_abrupt-4xCO2_r1i1p1f1_gn_04630101-04631231.nc')
ds_pr
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 365, bnds: 2, lat: 80, lon: 180)
# Coordinates:
#   * time       (time) object 0463-01-01 12:00:00 ... 0463-12-31 12:00:00
#   * lat        (lat) float64 -90.0 -84.82 -80.72 -77.22 ... 80.72 84.82 90.0
#   * lon        (lon) float64 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) object ...
#     lat_bnds   (lat, bnds) float64 ...
#     lon_bnds   (lon, bnds) float64 ...
#     pr         (time, lat, lon) float32 ...
# Attributes: (12/46)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  168630.0
#     contact:                Lijuan Li (ljli@mail.iap.ac.cn)
#     ...                     ...
#     title:                  FGOALS-g3 output prepared for CMIP6
#     tracking_id:            hdl:21.14100/b0a9e0ff-2425-47bd-86e1-8b56fe03cd0f
#     variable_id:            pr
#     variant_label:          r1i1p1f1
#     license:                CMIP6 model data produced by LASG, Institute of A...
#     cmor_version:           3.5.0

# %%
ds_pr.time[0:5]
# Out:
# <xarray.DataArray 'time' (time: 5)>
# array([cftime.DatetimeNoLeap(463, 1, 1, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(463, 1, 2, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(463, 1, 3, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(463, 1, 4, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(463, 1, 5, 12, 0, 0, 0, has_year_zero=True)],
#       dtype=object)
# Coordinates:
#   * time     (time) object 0463-01-01 12:00:00 ... 0463-01-05 12:00:00
# Attributes:
#     bounds:         time_bnds
#     axis:           T
#     long_name:      time
#     standard_name:  time
