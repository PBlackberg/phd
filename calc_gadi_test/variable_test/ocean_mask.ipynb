# %%
import xarray as xr

# %%
a = xr.open_dataset('/g/data/oi10/replicas/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r1i1p1f1/fx/sftlf/gr/v20180803/sftlf_fx_IPSL-CM6A-LR_historical_r1i1p1f1_gr.nc')
a
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/share/proj failed
# <xarray.Dataset>
# Dimensions:  (lat: 143, lon: 144)
# Coordinates:
#   * lat      (lat) float32 -90.0 -88.73 -87.46 -86.2 ... 86.2 87.46 88.73 90.0
#   * lon      (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#     type     |S255 ...
# Data variables:
#     sftlf    (lat, lon) float32 ...
# Attributes: (12/50)
#     Conventions:            CF-1.7 CMIP-6.2
#     creation_date:          2018-07-11T07:27:04Z
#     tracking_id:            hdl:21.14100/cc6c4852-271d-4c5a-adc3-42530ef19550
#     description:            CMIP6 historical
#     title:                  IPSL-CM6A-LR model output prepared for CMIP6 / CM...
#     activity_id:            CMIP
#     ...                     ...
#     name:                   /ccc/work/cont003/gencmip6/p86caub/IGCM_OUT/IPSLC...
#     further_info_url:       https://furtherinfo.es-doc.org/CMIP6.IPSL.IPSL-CM...
# ...

# %%
da = a['sftlf']
da
# Out:
# <xarray.DataArray 'sftlf' (lat: 143, lon: 144)>
# [20592 values with dtype=float32]
# Coordinates:
#   * lat      (lat) float32 -90.0 -88.73 -87.46 -86.2 ... 86.2 87.46 88.73 90.0
#   * lon      (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#     type     |S255 ...
# Attributes:
#     online_operation:  once
#     cell_methods:      area: mean
#     standard_name:     land_area_fraction
#     description:       Land Area Fraction
#     long_name:         Land Area Fraction
#     history:           none
#     units:             %
#     cell_measures:     area: areacella

# %%
da.plot()

# %%
da.where(da==0).plot()

# %%
(((da/100)-1)*(-1)).plot()
