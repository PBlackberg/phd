# %%
from getpass import getuser  # Libaray to copy things
from pathlib import Path  # Object oriented libary to deal with paths
from tempfile import (
    NamedTemporaryFile,
    TemporaryDirectory,
)  # Creating temporary Files/Dirs
from dask.utils import format_bytes
from distributed import (
    Client,
    progress,
    wait,
)  # Libaray to orchestrate distributed resources
from dask_jobqueue import SLURMCluster  # Setting up distributed memories via slurm
import numpy as np  # Pythons standard array library
import xarray as xr  # Libary to work with labeled n-dimensional data
import dask  # Distributed data libary
import dask.distributed
import multiprocessing
from subprocess import run, PIPE
import sys
import os
import warnings

warnings.filterwarnings(action="ignore")
import pandas as pd

dask.config.config.get("distributed").get("dashboard").update(
    {"link": "{JUPYTERHUB_SERVICE_PREFIX}/proxy/{port}/status"}
)

# %%
ncpu = multiprocessing.cpu_count()
processes = False
nworker = 2
threads = ncpu // nworker
print(
    f"Number of CPUs: {ncpu}, number of threads: {threads}, number of workers: {nworker}, processes: {processes}"
)
client = Client(
    processes=processes,
    threads_per_worker=threads,
    n_workers=nworker,
    memory_limit="128GB",
)
client
# Out:
# Number of CPUs: 256, number of threads: 128, number of workers: 2, processes: False
# <Client: 'inproc://136.172.124.5/4096851/1' processes=2 threads=256, memory=238.42 GiB>

# %%
# Define a global pattern to find the files
###cloud liquid water
glob_pattern_3d1 = "atm_2d_ml_2020"
## Define the paths of file 1 (dppp0016)
data_path1 = Path("/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029")
## Collect all file names with pathlib's rglob and list compression  -- cloud liquid water
file_names1 = sorted([str(f) for f in data_path1.rglob(f"*{glob_pattern_3d1}*.nc")])[:]

# %%
file_names1[0]
# Out:
# '/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200120T000000Z.nc'

# %%
a = xr.open_dataset('/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201231T000000Z.nc')
a
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, ncells: 20971520)
# Coordinates:
#   * time     (time) float64 2.02e+07
# Dimensions without coordinates: ncells
# Data variables: (12/36)
#     ps       (time, ncells) float32 ...
#     psl      (time, ncells) float32 ...
#     rsdt     (time, ncells) float32 ...
#     rsut     (time, ncells) float32 ...
#     rsutcs   (time, ncells) float32 ...
#     rlut     (time, ncells) float32 ...
#     ...       ...
#     tauu     (time, ncells) float32 ...
#     tauv     (time, ncells) float32 ...
#     sfcwind  (time, ncells) float32 ...
#     uas      (time, ncells) float32 ...
#     vas      (time, ncells) float32 ...
#     tas      (time, ncells) float32 ...
# Attributes:
#     CDI:                  Climate Data Interface version 1.8.3rc (http://mpim...
#     Conventions:          CF-1.6
#     number_of_grid_used:  15
#     grid_file_uri:        http://icon-downloads.mpimet.mpg.de/grids/public/mp...
#     uuidOfHGrid:          0f1e7d66-637e-11e8-913b-51232bb4d8f9
#     title:                ICON simulation
#     institution:          Max Planck Institute for Meteorology/Deutscher Wett...
#     source:               git@gitlab.dkrz.de:icon/icon-aes.git@add96e8c60ea3f...
#     history:              /work/mh0287/k203123/GIT/icon-aes-dyw2/bin/icon_dpp...
#     references:           see MPIM/DWD publications
#     comment:              Sapphire Dyamond (k203123) on m21233 (Linux 2.6.32-...

# %%
print(len(file_names1))
# Out:
# 343

# %%
dset1 = xr.open_mfdataset(
    file_names1[0:100], combine="by_coords", chunks="auto", engine="netcdf4", parallel=True
)
# Out:
# 2023-12-19 02:38:51,779 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-52740852-ca06-44b4-9f49-233442c10636
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201208T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:51,783 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-8e65803c-9d8a-450b-b929-fc515e226eb5
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201028T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:51,785 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-43765693-c313-4710-9f7b-76f36f87e0c6
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200714T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:51,790 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-70183252-cefa-4638-8bda-5c86e075f941
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200420T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:51,826 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-50835ff1-715d-4d72-92df-60a2d4967d85
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200919T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:51,829 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-b341228a-2843-4a9b-9bdb-9ffbaf23009f
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200307T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,152 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-8c4029fc-e1e4-4179-a3f9-512686f8ac59
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201214T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,154 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-a517c77d-770b-4e2d-8184-73b8c8b101b3
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200612T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,155 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-85f9546f-31b3-4afa-9eca-03b48e25b948
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201115T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,156 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-67eae418-4a27-4ef9-8d47-6fac8ffa846b
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200429T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,157 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-657963ec-adad-430d-abcd-1c0b8608e07a
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200703T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,158 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-a0a06969-3d2c-4671-b9ab-d7cddf3879fe
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201006T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "RuntimeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,160 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-9279e723-a3e9-4ed8-a00c-d3a0c3b1bcb4
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200229T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,162 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-63583ac2-81ef-4a55-b1c5-d96439cb0eb7
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200605T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,163 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-424e5818-79f6-412e-86b8-d0a6cb056697
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200801T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,164 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-aaaffe9a-dd9c-4283-9ea8-b4ab418ddbce
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200130T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "RuntimeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,165 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-28385866-89be-4798-9ed1-ee5f19705516
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201217T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,167 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-a66f4d49-7051-4cc5-9f30-b6a2f6eb1f00
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200423T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "RuntimeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,169 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-520dc26e-a035-4548-bc8a-bd8abeceffdf
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201019T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,171 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-b611d2e8-e43c-4e73-9414-4d1518ece786
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200709T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,172 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-b9b5d3bf-ea65-431b-9d20-79c5d70edd28
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200316T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,175 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-ba17bca6-591e-4ead-98d6-1cb2f2b79b81
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200616T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,178 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-3dfa577f-1651-416c-8cb1-f3e8059b4c47
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201221T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,179 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-4cdb7e14-d345-49ea-b3cb-30e940944203
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200311T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,180 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-c8f21783-64a9-4b02-a012-1e8af72f15ff
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200718T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,184 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-68fd5a52-02eb-4ef8-8369-2429b35773c4
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200419T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "RuntimeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,187 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-fdfe4ac5-fcec-4f8c-ae15-e290b2298c83
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200806T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,188 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-ae3aea86-b42d-4073-89bd-c39066e7877b
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200425T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,189 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-b6b16e26-7850-4222-93a7-3a70a8ad0768
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200129T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,190 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-c9961cc7-938a-47f8-810a-44873b325b55
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200410T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,191 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-1d989600-deae-4a40-afcb-dfcc0ceaff13
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200704T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,197 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-6c7e3287-f805-4cfa-9b3a-eac965c600be
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200720T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,198 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-1c356615-aed0-4a8a-9e15-c5e92d2e1d52
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200927T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,199 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-d22d0645-0b14-4b6c-b824-ec2f0b17359e
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200412T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,200 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-e557ef61-b6b4-4347-9167-206273618c42
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200219T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,201 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-71886491-27e2-4895-86c1-4442b56c1f80
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200916T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,204 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-d1d4688f-bc20-484c-b0bb-1158f9e8bef9
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200608T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,205 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-f567b894-96bc-42e3-90d1-1e7b425cb8bd
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200510T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,206 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-9df7577c-3a4d-4df6-8993-1acf9f399b8e
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201027T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,207 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-c7708911-451a-4295-9ae4-560e96ab40d6
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201001T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,208 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-7dce25b6-850b-4c92-a4ed-63f12e49ae94
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201227T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,209 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-ad0cbeb2-0012-47d5-8bc3-27db093bd709
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200624T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,210 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-f4297ca4-ef1f-463b-b177-49dcf68d564e
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201014T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,211 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-d4664294-5ada-4a74-be58-f9b9de808ede
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201011T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,213 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-6f5b346b-2066-43e9-97a4-0d3f60ef5ffa
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201109T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,214 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-f824a0c2-b54a-4140-991b-a21c56dd896e
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201215T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,215 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-e2092776-9baa-42eb-806f-6cb7384a5afd
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200831T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,216 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-f1e79b3e-4c66-407d-a7bb-350a52d4c33c
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200907T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,217 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-75c0f567-380e-4efd-a5fe-7bf71d29ed59
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200313T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,220 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-a01a475c-8b09-48ea-b3e3-869eafadd1ec
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200622T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,223 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-c7c5f26c-3d91-4722-8068-5f7a180ef8e9
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201204T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,225 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-c70a3bdb-f6a3-4796-9a2a-ec1e57ce4cd0
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200518T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,226 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-c80ed362-94fe-4ac3-95f6-3a127c850264
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200123T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,227 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-2fd373fb-5066-4e45-a5bc-65bf0355d6f6
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200726T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,228 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-d5b23217-ed38-4e6e-b5f7-e9068190bf66
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200329T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,229 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-525423b1-f534-43e8-a8ef-9cc067e183d0
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200226T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,230 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-070aebc1-b884-4c9e-9d6f-9a9025f552a2
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200428T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,231 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-894386e8-76eb-4c2f-8ac5-a68ef0273bf6
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200727T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "RuntimeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,232 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-2d788f2d-a260-44ad-a5bd-cc3a5188ce0e
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200403T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,233 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-1666910d-8cb1-4692-8c0f-04def3da9dea
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200516T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,234 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-c7efbf6c-f3f6-41cd-ad8b-bfaa9a9a993a
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200507T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,235 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-a30246d5-c730-4f5a-bb35-fe6937ea5460
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201206T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,236 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-cbe0750a-0a10-4a7d-a40e-6046c17380aa
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201212T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,237 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-6c8b96b4-6fc9-450f-9811-d772c7c3766f
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200406T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,240 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-c84e7ec8-3bdc-474b-a05d-57e4f672c37f
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200824T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,240 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-6e4a2596-b43e-4981-af07-ed11fbe54296
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201025T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,241 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-4c5587c8-b4cd-4ec4-a846-66c78c010136
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200823T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,241 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-48a6337b-79da-4052-8eb0-0a0b7b92daba
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201017T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,242 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-d5c95e24-2a7b-44b1-8258-c0f765d631f0
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201104T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,243 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-69777c24-0940-4596-b570-63e01cc12543
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200930T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,244 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-dcc45214-df9b-424a-b63d-a6f6a988e578
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200809T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,245 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-c3df49f7-c6e6-49d1-af27-c1a31038566b
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200816T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,247 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-6fc62e0a-3ef8-4799-ac89-02fe4523225d
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200813T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,251 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-e36fe050-b3df-441c-a091-b3205faa4f18
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200212T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,252 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-3c738ec9-680f-43ee-a4a6-920d9c07832b
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200505T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,253 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-6dfcc825-caeb-4b27-beae-4f08a944d507
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201201T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,254 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-32434caa-c35e-4275-b87e-cd0ae81d4aac
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201118T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,254 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-b1fa6fcb-b62c-42d9-8d03-0df1441d3d3c
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201030T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,255 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-0c63d5a8-9e27-4fc3-b057-dcf7d8dca06d
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200308T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,256 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-eb7fa64a-84f8-46d1-b9e3-2d361872fad6
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201119T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,257 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-ab59e12a-e3cb-4bc4-90a6-c58d6be0fd25
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200708T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,259 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-abd94a29-9d26-418a-92e5-ec1452e23ab9
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200802T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,259 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-fd914b3b-9ed0-403b-999e-d67bb4360f02
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200527T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,260 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-ce92b8d6-ad7c-422a-8136-84e33b111772
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201106T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,261 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-b17cb450-e5fb-43a3-8958-9d6dcf49b1e2
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201021T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,262 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-66b4a1f3-25fc-4dc4-8019-060b05a1e440
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200830T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,263 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-018b141b-62b8-4225-9f2d-8cae0c22a0b9
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201113T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "RuntimeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,264 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-d3bbf6c2-e467-445e-a59b-45819aa1a3cb
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201008T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,265 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-d0089bd7-15a1-4f94-8855-795515444f76
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200327T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,265 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-2e471955-a259-4fec-b6c5-47884c6188ae
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201020T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,266 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-063f7f5f-40d7-4821-9bd6-baf5ae8af04f
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200517T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,267 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-e17a29b6-5741-4675-8452-9078a6534765
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200715T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,270 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-45b6cb00-9ace-4044-aa7a-b07499943d9b
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200305T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,271 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-357a8367-2193-4c89-b819-9088b8244f7a
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201129T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,272 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-69c2f22f-6d0d-4ac2-a62d-db0d17e8f3b8
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200619T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,273 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-e039a2dd-e4e0-4ad4-a107-a3d511053ca0
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201225T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,274 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-78e55cbe-536d-435b-8e23-d77c8daaf3b3
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200322T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,275 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-f36057e4-fba9-4914-a370-5847294d2504
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200208T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# ...
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,356 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-7fd47e00-3112-4d01-9507-307b3e9d5719
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200330T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,357 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-64bd00c8-858d-4ab2-aae8-4fc599ab0353
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200309T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,357 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-a1185dc9-795a-48ba-ae25-7242fbca66d9
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200312T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,358 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-e1275cb9-7614-47bb-8ecd-0c13b63b7e1c
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200731T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,359 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-44533a93-8104-458b-94dd-1cf419eb263c
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200828T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "RuntimeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,369 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-0b893532-c702-4caa-87b8-2e1157aed409
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200711T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,373 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-70e0df25-fb85-43ce-9bc2-62af5c604715
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200404T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,373 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-86ed01fa-985e-4900-8f8a-236662d394d3
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200901T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,374 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-60dd1144-bbbd-43c0-8337-febe1f452020
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200522T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,380 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-87971635-3da9-4271-9e3e-150e49eca5db
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201012T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,384 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-14375fbe-d62a-41df-83cb-e90dcccc5ae9
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200120T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,385 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-81be1434-590c-471d-90cb-9a831e335747
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201114T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,385 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-a7a9bec7-c8be-4c59-b034-352a024b1ca5
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200314T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,386 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-3b59b349-5e65-4e41-a9a1-48279e666a6b
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200203T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,395 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-05b9dfca-d086-4d88-8ab6-0adf9da7e981
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200422T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,397 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-0c0131e6-d775-4d3a-adef-0d8d6f2b00d1
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201110T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,403 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-2e6585c5-67a8-4f9d-96d4-eb80cdaa7525
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200301T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,404 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-e809a6f3-ad03-49d3-b3cc-fcdc8f8bc0d5
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201230T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,404 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-c8517638-c924-4d98-ab94-6bad8ef6c4d2
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200826T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,423 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-5fdaa409-e83d-4b60-b54f-70076bf7458f
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201122T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,427 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-ca01da5d-424c-47ff-ab57-8de6f54a641a
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20201003T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,435 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-253bec8b-9d8f-4d3b-b7e9-168c822e1ec8
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200807T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,436 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-1191ef09-7390-43be-ae13-77a069d3b3aa
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200604T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:38:52,437 - distributed.worker - WARNING - Compute Failed
# Key:       open_dataset-3c2bd75e-3cb1-4f56-8331-818f04e71253
# Function:  execute_task
# args:      ((<function apply at 0x7fa4a26a1ea0>, <function open_dataset at 0x7fa482dae8c0>, ['/work/mh0287/k203123/Dyamond++/icon-aes-dyw2/experiments/dpp0029/dpp0029_atm_2d_ml_20200915T000000Z.nc'], (<class 'dict'>, [['engine', 'netcdf4'], ['chunks', 'auto']])))
# kwargs:    {}
# Exception: "AttributeError('NetCDF: Not a valid ID')"
#
# 2023-12-19 02:39:01,297 - distributed.worker - ERROR - Exception during execution of task getattr-0e92c90d-f004-4fd8-82d7-89aea19223b0.
# Traceback (most recent call last):
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/distributed/worker.py", line 2389, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'open_dataset-659b56db-88e0-4f2b-9e53-e3662349c825'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/distributed/worker.py", line 2270, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/distributed/worker.py", line 2393, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'open_dataset-659b56db-88e0-4f2b-9e53-e3662349c825'
# 2023-12-19 02:39:01,327 - distributed.worker - ERROR - Exception during execution of task getattr-bde8e036-7e38-4eb2-8ddd-14cd90775f09.
# Traceback (most recent call last):
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/distributed/worker.py", line 2389, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'open_dataset-330be235-eb86-4576-8a34-04e2ce8f6f8b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/distributed/worker.py", line 2270, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/distributed/worker.py", line 2393, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'open_dataset-330be235-eb86-4576-8a34-04e2ce8f6f8b'
# 2023-12-19 02:39:01,351 - distributed.worker - ERROR - Exception during execution of task getattr-3a7962b0-f027-4e9c-bfbe-3ea17f25cda7.
# Traceback (most recent call last):
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/distributed/worker.py", line 2389, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'open_dataset-0b4b6b43-a7c0-4f33-b936-7089cf35905a'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/distributed/worker.py", line 2270, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/distributed/worker.py", line 2393, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'open_dataset-0b4b6b43-a7c0-4f33-b936-7089cf35905a'

# %%
dset1
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 223, ncells: 20971520)
# Coordinates:
#   * time     (time) float64 2.02e+07 2.02e+07 2.02e+07 ... 2.02e+07 2.02e+07
# Dimensions without coordinates: ncells
# Data variables: (12/36)
#     ps       (time, ncells) float32 dask.array<chunksize=(2, 16777214), meta=np.ndarray>
#     psl      (time, ncells) float32 dask.array<chunksize=(2, 16777214), meta=np.ndarray>
#     rsdt     (time, ncells) float32 dask.array<chunksize=(2, 16777214), meta=np.ndarray>
#     rsut     (time, ncells) float32 dask.array<chunksize=(2, 16777214), meta=np.ndarray>
#     rsutcs   (time, ncells) float32 dask.array<chunksize=(2, 16777214), meta=np.ndarray>
#     rlut     (time, ncells) float32 dask.array<chunksize=(2, 16777214), meta=np.ndarray>
#     ...       ...
#     tauu     (time, ncells) float32 dask.array<chunksize=(2, 16777214), meta=np.ndarray>
#     tauv     (time, ncells) float32 dask.array<chunksize=(2, 16777214), meta=np.ndarray>
#     sfcwind  (time, ncells) float32 dask.array<chunksize=(2, 16777214), meta=np.ndarray>
#     uas      (time, ncells) float32 dask.array<chunksize=(2, 16777214), meta=np.ndarray>
#     vas      (time, ncells) float32 dask.array<chunksize=(2, 16777214), meta=np.ndarray>
#     tas      (time, ncells) float32 dask.array<chunksize=(2, 16777214), meta=np.ndarray>
# Attributes:
#     CDI:                  Climate Data Interface version 1.8.3rc (http://mpim...
#     Conventions:          CF-1.6
#     number_of_grid_used:  15
#     grid_file_uri:        http://icon-downloads.mpimet.mpg.de/grids/public/mp...
#     uuidOfHGrid:          0f1e7d66-637e-11e8-913b-51232bb4d8f9
#     title:                ICON simulation
#     institution:          Max Planck Institute for Meteorology/Deutscher Wett...
#     source:               git@gitlab.dkrz.de:icon/icon-aes.git@432d202fb95b6d...
#     history:              /work/mh0287/k203123/GIT/icon-aes-dyw2/bin/icon_dpp...
#     references:           see MPIM/DWD publications
#     comment:              Sapphire Dyamond (k203123) on m21281 (Linux 2.6.32-...

# %%
format_bytes(dset1.nbytes)
# Out:
# '627.19 GiB'

# %%
pr_data = dset1["pr"]
pr_data
# Out:
# <xarray.DataArray 'pr' (time: 223, ncells: 20971520)>
# dask.array<concatenate, shape=(223, 20971520), dtype=float32, chunksize=(2, 16777214), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) float64 2.02e+07 2.02e+07 2.02e+07 ... 2.02e+07 2.02e+07
# Dimensions without coordinates: ncells
# Attributes:
#     standard_name:                pr
#     long_name:                    precipitation flux
#     units:                        kg m-2 s-1
#     param:                        52.1.0
#     CDI_grid_type:                unstructured
#     number_of_grid_in_reference:  1

# %%
time1 = pd.to_datetime(pr_data.time.data, format="%Y%m%d")
hours = (pr_data.time.values % 1) * 24
time2 = pd.to_datetime(hours, format="%H")
timenew = pd.to_datetime(pd.to_numeric(time2 - time2[0]) + pd.to_numeric(time1))

# %%
pr_data["time"] = timenew

# %%
pr_data.time
# Out:
# <xarray.DataArray 'time' (time: 223)>
# array(['2020-01-20T00:00:00.000000000', '2020-01-20T06:00:00.000000000',
#        '2020-01-20T12:00:00.000000000', ..., '2020-04-26T00:00:00.000000000',
#        '2020-04-27T00:00:00.000000000', '2020-04-28T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2020-01-20 2020-01-20T06:00:00 ... 2020-04-28

# %%
pr_data.time[0:5] # 6 hourly
# Out:
# <xarray.DataArray 'time' (time: 5)>
# array(['2020-01-20T00:00:00.000000000', '2020-01-20T06:00:00.000000000',
#        '2020-01-20T12:00:00.000000000', '2020-01-20T18:00:00.000000000',
#        '2020-01-21T00:00:00.000000000'], dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2020-01-20 2020-01-20T06:00:00 ... 2020-01-21

# %%
pr_daily = (
    pr_data.sel(time=slice("2020-02-10", "2020-03-10"))
    .resample(time="1D", skipna=True)
    .mean()
)

# %%
pr_daily
# Out:
# <xarray.DataArray 'pr' (time: 30, ncells: 20971520)>
# dask.array<stack, shape=(30, 20971520), dtype=float32, chunksize=(1, 16777214), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2020-02-10 2020-02-11 ... 2020-03-10
# Dimensions without coordinates: ncells
# Attributes:
#     standard_name:                pr
#     long_name:                    precipitation flux
#     units:                        kg m-2 s-1
#     param:                        52.1.0
#     CDI_grid_type:                unstructured
#     number_of_grid_in_reference:  1

# %%
####grid information
filegrid = "/pool/data/ICON/grids/public/mpim/0015/icon_grid_0015_R02B09_G.nc"
dsetgrid = xr.open_dataset(filegrid, chunks="auto", engine="netcdf4").rename(
    {"cell": "ncells"}
)

# %%
dsetgrid
# Out:
# <xarray.Dataset>
# Dimensions:                         (ncells: 20971520, nv: 3, vertex: 10485762,
#                                      ne: 6, edge: 31457280, no: 4, nc: 2,
#                                      max_stored_decompositions: 4, two_grf: 2,
#                                      cell_grf: 14, max_chdom: 1, edge_grf: 24,
#                                      vert_grf: 13)
# Coordinates:
#     clon                            (ncells) float64 dask.array<chunksize=(16777216,), meta=np.ndarray>
#     clat                            (ncells) float64 dask.array<chunksize=(16777216,), meta=np.ndarray>
#     vlon                            (vertex) float64 dask.array<chunksize=(10485762,), meta=np.ndarray>
#     vlat                            (vertex) float64 dask.array<chunksize=(10485762,), meta=np.ndarray>
#     elon                            (edge) float64 dask.array<chunksize=(16777216,), meta=np.ndarray>
#     elat                            (edge) float64 dask.array<chunksize=(16777216,), meta=np.ndarray>
# Dimensions without coordinates: ncells, nv, vertex, ne, edge, no, nc,
#                                 max_stored_decompositions, two_grf, cell_grf,
#                                 max_chdom, edge_grf, vert_grf
# Data variables: (12/91)
#     clon_vertices                   (ncells, nv) float64 dask.array<chunksize=(16777214, 1), meta=np.ndarray>
#     clat_vertices                   (ncells, nv) float64 dask.array<chunksize=(16777214, 1), meta=np.ndarray>
#     vlon_vertices                   (vertex, ne) float64 dask.array<chunksize=(5592404, 3), meta=np.ndarray>
#     vlat_vertices                   (vertex, ne) float64 dask.array<chunksize=(5592404, 3), meta=np.ndarray>
#     elon_vertices                   (edge, no) float64 dask.array<chunksize=(16777214, 1), meta=np.ndarray>
#     elat_vertices                   (edge, no) float64 dask.array<chunksize=(16777214, 1), meta=np.ndarray>
#     ...                              ...
#     edge_dual_normal_cartesian_x    (edge) float64 dask.array<chunksize=(16777216,), meta=np.ndarray>
#     edge_dual_normal_cartesian_y    (edge) float64 dask.array<chunksize=(16777216,), meta=np.ndarray>
#     edge_dual_normal_cartesian_z    (edge) float64 dask.array<chunksize=(16777216,), meta=np.ndarray>
#     cell_circumcenter_cartesian_x   (ncells) float64 dask.array<chunksize=(16777216,), meta=np.ndarray>
#     cell_circumcenter_cartesian_y   (ncells) float64 dask.array<chunksize=(16777216,), meta=np.ndarray>
#     cell_circumcenter_cartesian_z   (ncells) float64 dask.array<chunksize=(16777216,), meta=np.ndarray>
# Attributes: (12/43)
#     title:                    ICON grid description
#     institution:              Max Planck Institute for Meteorology/Deutscher ...
#     source:                   git@git.mpimet.mpg.de:GridGenerator.git
#     revision:                 d00fcac1f61fa16c686bfe51d1d8eddd09296cb5
#     date:                     20180529 at 222250
#     user_name:                Rene Redler (m300083)
#     ...                       ...
#     topography:               modified SRTM30
#     subcentre:                1
#     number_of_grid_used:      15
#     history:                  Thu Aug 16 11:05:44 2018: ncatted -O -a ICON_gr...
#     ICON_grid_file_uri:       http://icon-downloads.mpimet.mpg.de/grids/publi...
#     NCO:                      netCDF Operators version 4.7.5 (Homepage = http...

# %%
pr_mean = pr_daily.mean(dim="time").compute()

# %%
pr_mean
# Out:
# <xarray.DataArray 'pr' (ncells: 20971520)>
# array([1.3562195e-05, 1.3487518e-05, 1.3580961e-05, ..., 3.3366538e-05,
#        3.4132456e-05, 3.4461165e-05], dtype=float32)
# Dimensions without coordinates: ncells

# %%
format_bytes(pr_mean.nbytes)
# Out:
# '80.00 MiB'

# %%
pr_mean = pr_mean.assign_coords(
    clon=("ncells", dsetgrid.clon.data * 180 / np.pi),
    clat=("ncells", dsetgrid.clat.data * 180 / np.pi),
)

# %%
pr_mean
# Out:
# <xarray.DataArray 'pr' (ncells: 20971520)>
# array([1.3562195e-05, 1.3487518e-05, 1.3580961e-05, ..., 3.3366538e-05,
#        3.4132456e-05, 3.4461165e-05], dtype=float32)
# Coordinates:
#     clon     (ncells) float64 dask.array<chunksize=(16777216,), meta=np.ndarray>
#     clat     (ncells) float64 dask.array<chunksize=(16777216,), meta=np.ndarray>
# Dimensions without coordinates: ncells

# %%
pr_mean.clon[0:5]
# Out:
# <xarray.DataArray 'clon' (ncells: 5)>
# dask.array<getitem, shape=(5,), dtype=float64, chunksize=(5,), chunktype=numpy.ndarray>
# Coordinates:
#     clon     (ncells) float64 dask.array<chunksize=(5,), meta=np.ndarray>
#     clat     (ncells) float64 dask.array<chunksize=(5,), meta=np.ndarray>
# Dimensions without coordinates: ncells

# %%
from cartopy import crs as ccrs  # Cartography library
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import cartopy.feature as cfeature
from matplotlib.ticker import MultipleLocator, FormatStrFormatter, AutoMinorLocator
from matplotlib import pyplot as plt  # Standard Plotting library
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# %%
# fig = plt.figure(figsize=(10, 6))
# ax = fig.add_subplot(111, projection=ccrs.PlateCarree(central_longitude=0))
# cs1 = plt.scatter(
#     pr_mean.clon[::100],
#     pr_mean.clat[::100],
#     s=0.1,
#     c=pr_mean[::100] * 24 * 3600,
#     vmin=0,
#     vmax=14,
#     cmap="YlGnBu",
#     transform=ccrs.PlateCarree(),
# )
# cb1 = plt.colorbar(cs1, extend="max", orientation="horizontal", shrink=0.6, pad=0.1)
# cb1.ax.set_xlabel("Precipitation (mm day$^{-1}$)", fontsize=12)
# cb1.ax.tick_params(labelsize=12)
# ax.coastlines(resolution="110m", linewidth=0.6)
# ax.set_extent([-180, 179.9, -80, 80], crs=ccrs.PlateCarree())
# ax.set_yticks(np.arange(-80, 81, 20), crs=ccrs.PlateCarree())
# lat_formatter = LatitudeFormatter()
# ax.yaxis.set_major_formatter(lat_formatter)
# ax.set_xticks(np.arange(-180, 179, 60), crs=ccrs.PlateCarree())
# lon_formatter = LongitudeFormatter(zero_direction_label=True)
# ax.xaxis.set_major_formatter(lon_formatter)
# ax.tick_params(labelsize=12)
# ax.set_xlabel(None)
# ax.set_ylabel(None)
# Out:
# Text(0, 0.5, '')

# %%
# pr_mean_trop = pr_mean.sel(lat = slice(-35, 35))
# pr_mena_trop
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 pr_mean_trop = pr_mean.sel(lat = slice(-35, 35))
#       2 pr_mena_trop
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/dataarray.py:1531, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1421 def sel(
#    1422     self: T_DataArray,
#    1423     indexers: Mapping[Any, Any] | None = None,
#    (...)
#    1427     **indexers_kwargs: Any,
#    1428 ) -> T_DataArray:
#    1429     """Return a new DataArray whose data is given by selecting index
#    1430     labels along the specified dimension(s).
#    1431
#    (...)
#    1529     Dimensions without coordinates: points
#    1530     """
# -> 1531     ds = self._to_temp_dataset().sel(
#    1532         indexers=indexers,
#    1533         drop=drop,
#    1534         method=method,
#    1535         tolerance=tolerance,
#    1536         **indexers_kwargs,
#    1537     )
#    1538     return self._from_temp_dataset(ds)
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/dataset.py:2580, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2519 """Returns a new dataset with each array indexed by tick labels
#    2520 along the specified dimension(s).
#    2521
#    (...)
#    2577 DataArray.sel
#    2578 """
#    2579 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 2580 query_results = map_index_queries(
#    2581     self, indexers=indexers, method=method, tolerance=tolerance
#    2582 )
#    2584 if drop:
#    2585     no_scalar_variables = {}
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/indexing.py:181, in map_index_queries(obj, indexers, method, tolerance, **indexers_kwargs)
#     178     options = {"method": method, "tolerance": tolerance}
#     180 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "map_index_queries")
# --> 181 grouped_indexers = group_indexers_by_index(obj, indexers, options)
#     183 results = []
#     184 for index, labels in grouped_indexers:
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/indexing.py:145, in group_indexers_by_index(obj, indexers, options)
#     143     raise KeyError(f"no index found for coordinate {key!r}")
#     144 elif key not in obj.dims:
# --> 145     raise KeyError(f"{key!r} is not a valid dimension or coordinate")
#     146 elif len(options):
#     147     raise ValueError(
#     148         f"cannot supply selection options {options!r} for dimension {key!r}"
#     149         "that has no associated coordinate or index"
#     150     )
#
# KeyError: "'lat' is not a valid dimension or coordinate"
