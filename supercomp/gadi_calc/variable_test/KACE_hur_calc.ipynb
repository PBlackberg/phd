# %%
import xarray as xr
import numpy as np

# %%
folder = '/g/data/k10/cb4968/data/metrics/hur/hur_tMean/cmip6/'

# %%
filename = 'KIOST-ESM_hur_tMean_monthly_historical_regridded.nc'
a = xr.open_dataset(f'{folder}/{filename}')['hur_tMean']

# %%
filename = 'KACE-1-0-G_hur_tMean_monthly_ssp585_regridded.nc'
b = xr.open_dataset(f'{folder}/{filename}')['hur_tMean']

# %%
a.plot()

# %%
b.plot()
