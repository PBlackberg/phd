# %%
import xarray as xr

# %%
a = xr.open_dataset('/g/data/oi10/replicas/CMIP6/CMIP/MIROC/MIROC6/historical/r1i1p1f1/Amon/ta/gn/v20190311/ta_Amon_MIROC6_historical_r1i1p1f1_gn_197001-197912.nc')
a
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/share/proj failed
# <xarray.Dataset>
# Dimensions:    (time: 120, bnds: 2, plev: 19, lat: 128, lon: 256)
# Coordinates:
#   * time       (time) datetime64[ns] 1970-01-16T12:00:00 ... 1979-12-16T12:00:00
#   * plev       (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * lat        (lat) float64 -88.93 -87.54 -86.14 -84.74 ... 86.14 87.54 88.93
#   * lon        (lon) float64 0.0 1.406 2.812 4.219 ... 354.4 355.8 357.2 358.6
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] ...
#     lat_bnds   (lat, bnds) float64 ...
#     lon_bnds   (lon, bnds) float64 ...
#     ta         (time, plev, lat, lon) float32 ...
# Attributes: (12/44)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
# ...

# %%
da = a['ta'].sel(plev = 700e2)
da
# Out:
# <xarray.DataArray 'ta' (time: 120, lat: 128, lon: 256)>
# [3932160 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 1970-01-16T12:00:00 ... 1979-12-16T12:00:00
#     plev     float64 7e+04
#   * lat      (lat) float64 -88.93 -87.54 -86.14 -84.74 ... 86.14 87.54 88.93
#   * lon      (lon) float64 0.0 1.406 2.812 4.219 ... 354.4 355.8 357.2 358.6
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Air Temperature
#     comment:        Air Temperature
#     units:          K
#     original_name:  T
#     cell_methods:   time: mean
#     cell_measures:  area: areacella
#     history:        2019-02-13T11:38:02Z altered by CMOR: replaced missing va...

# %%
da.isel(time=0).plot()
