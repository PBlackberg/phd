# %%
import xarray as xr
import numpy as np

# %%
a = xr.open_dataset('/g/data/oi10/replicas/CMIP6/CMIP/KIOST/KIOST-ESM/historical/r1i1p1f1/Amon/clivi/gr1/v20210601/clivi_Amon_KIOST-ESM_historical_r1i1p1f1_gr1_185001-201412.nc')
a
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/share/proj failed
# <xarray.Dataset>
# Dimensions:    (time: 1980, lon: 192, lat: 96, bnds: 2)
# Coordinates:
#   * time       (time) object 1850-01-17 12:00:00 ... 2014-12-17 12:00:00
#   * lon        (lon) float64 0.9375 2.812 4.688 6.563 ... 355.3 357.2 359.1
#   * lat        (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 86.21 88.11 90.0
# Dimensions without coordinates: bnds
# Data variables:
#     lat_bnds   (lat, bnds) float64 ...
#     lon_bnds   (lon, bnds) float64 ...
#     time_bnds  (time, bnds) object ...
#     clivi      (time, lat, lon) float32 ...
# Attributes: (12/48)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  488370
#     contact:                YoungHo Kim (yhokim@pknu.ac.kr & yhkimstar@gmail....
# ...

# %%
da = a['clivi']
da
# Out:
# <xarray.DataArray 'clivi' (time: 1980, lat: 96, lon: 192)>
# [36495360 values with dtype=float32]
# Coordinates:
#   * time     (time) object 1850-01-17 12:00:00 ... 2014-12-17 12:00:00
#   * lon      (lon) float64 0.9375 2.812 4.688 6.563 ... 353.4 355.3 357.2 359.1
#   * lat      (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 84.32 86.21 88.11 90.0
# Attributes:
#     standard_name:  atmosphere_mass_content_of_cloud_ice
#     long_name:      Ice Water Path
#     comment:        mass of ice water in the column divided by the area of th...
#     units:          kg m-2
#     cell_methods:   area: time: mean
#     cell_measures:  area: areacella

# %%
da.min()
# Out:
# <xarray.DataArray 'clivi' ()>
# array(0.)

# %%
da.max()
# Out:
# <xarray.DataArray 'clivi' ()>
# array(1.549142)

# %%
np.percentile(da, 1)
# Out:
# 0.00025666919536888606

# %%
b = xr.open_dataset('/g/data/oi10/replicas/CMIP6/CMIP/KIOST/KIOST-ESM/historical/r1i1p1f1/Amon/cli/gr1/v20210601/cli_Amon_KIOST-ESM_historical_r1i1p1f1_gr1_185001-201412.nc')
b
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/share/proj failed
# <xarray.Dataset>
# Dimensions:    (plev: 19, time: 1980, lon: 192, lat: 96, bnds: 2)
# Coordinates:
#   * plev       (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * time       (time) object 1850-01-17 12:00:00 ... 2014-12-17 12:00:00
#   * lon        (lon) float64 0.9375 2.812 4.688 6.563 ... 355.3 357.2 359.1
#   * lat        (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 86.21 88.11 90.0
# Dimensions without coordinates: bnds
# Data variables:
#     lat_bnds   (lat, bnds) float64 ...
#     lon_bnds   (lon, bnds) float64 ...
#     time_bnds  (time, bnds) object ...
#     cli        (time, plev, lat, lon) float32 ...
# Attributes: (12/48)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  488370
# ...

# %%
da_b = b['cli'].isel(time=slice(0,4))
da_b
# Out:
# <xarray.DataArray 'cli' (time: 4, plev: 19, lat: 96, lon: 192)>
# [1400832 values with dtype=float32]
# Coordinates:
#   * plev     (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * time     (time) object 1850-01-17 12:00:00 ... 1850-04-17 00:00:00
#   * lon      (lon) float64 0.9375 2.812 4.688 6.563 ... 353.4 355.3 357.2 359.1
#   * lat      (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 84.32 86.21 88.11 90.0
# Attributes:
#     standard_name:   mass_fraction_of_cloud_ice_in_air
#     long_name:       Mass Fraction of Cloud Ice
#     comment:         Includes both large-scale and convective cloud. This is ...
#     units:           kg kg-1
#     original_units:  1
#     history:         2019-10-28T02:47:22Z altered by CMOR: Converted units fr...
#     cell_methods:    area: time: mean
#     cell_measures:   area: areacella

# %%
da_b['plev'][0]
# Out:
# <xarray.DataArray 'plev' ()>
# array(100000.)
# Coordinates:
#     plev     float64 1e+05
# Attributes:
#     units:          Pa
#     axis:           Z
#     positive:       down
#     long_name:      pressure
#     standard_name:  air_pressure

# %%
da_b.min()
# Out:
# <xarray.DataArray 'cli' ()>
# array(0.)

# %%
da_b.max()
# Out:
# <xarray.DataArray 'cli' ()>
# array(0.00012845)
