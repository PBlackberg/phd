# %%
import xarray as xr

# %%
a = xr.open_dataset('/g/data/oi10/replicas/CMIP6/CMIP/INM/INM-CM5-0/historical/r1i1p1f1/Amon/ta/gr1/v20190610/ta_Amon_INM-CM5-0_historical_r1i1p1f1_gr1_197001-197912.nc')
a
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/share/proj failed
# <xarray.Dataset>
# Dimensions:    (time: 120, bnds: 2, plev: 19, lat: 120, lon: 180)
# Coordinates:
#   * time       (time) object 1970-01-16 12:00:00 ... 1979-12-16 12:00:00
#   * plev       (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * lat        (lat) float64 -89.25 -87.75 -86.25 -84.75 ... 86.25 87.75 89.25
#   * lon        (lon) float64 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) object ...
#     lat_bnds   (lat, bnds) float64 ...
#     lon_bnds   (lon, bnds) float64 ...
#     ta         (time, plev, lat, lon) float32 ...
# Attributes: (12/47)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  90885.0
# ...

# %%
da = a['ta']
da
# Out:
# <xarray.DataArray 'ta' (time: 120, plev: 19, lat: 120, lon: 180)>
# [49248000 values with dtype=float32]
# Coordinates:
#   * time     (time) object 1970-01-16 12:00:00 ... 1979-12-16 12:00:00
#   * plev     (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * lat      (lat) float64 -89.25 -87.75 -86.25 -84.75 ... 86.25 87.75 89.25
#   * lon      (lon) float64 0.0 2.0 4.0 6.0 8.0 ... 350.0 352.0 354.0 356.0 358.0
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Air Temperature
#     comment:        Air Temperature
#     units:          K
#     original_name:  ta
#     cell_methods:   time: mean (interval: 1 month)
#     cell_measures:  area: areacella

# %%
da.isel(time=0).sel(plev = 1000e2).plot()
